# %% [markdown]
# This program was designed to analyze vehicle performance data and simulate basic vehicle dynamics. Using an interactive dashboard to allow the user to specify which data they would like to visualize and which car types they would like to analyze. As a Mechanical Engineering assignment this program has helped us better understand not only how to use different python tools such as loops, matplotlib, numpy, and other modules but also helped us understand how vehicles work and what kind of data is collected by engineers to test and analyze vehicle performance.
#
# **Some of our key functions:**
#
#
# **User Interface**
# The User Interface function is one of the most important functions in our program. Without it all of the data would be generated at the same time which would be overwhelming. This function allows the user to select what information they want and have it provided to them, without the undesired data getting in the way.
#
# **Organize Data**
# The organize data function is the backbone of the program. It reads the CSV file and organizes the data. It puts all of the data into different dictionaries and lists depending on the kind of car it relates to, this is important as most of our graph functions can only process one of them at a time. It also feeds into our other calculation functions.
#
# **Basic Statistics**
# Calculates various statistics that might be significant when reviewing the different vehicles and allows these to be used in other functions more easily.
#
# **Fuel Efficiency**
# This function calculates the fuel efficiency of a specific car that is chosen by the user, this information is used in many places throughout our other functions, specifically the graphing and fuel cost functions.
#
# **Fuel Cost**
# This function calculates the fuel cost of a car type with known fuel efficiency and is another statistic that can be provided should the user ask for it.
#
# **Generate Time Series Graphs**
# This function is used to generate graphs for our program, specifically the given data over a period of time. The graphs can be created one at a time or all together. That  allows us to compare the different cars in a more direct and visual way.
#
# **Generate Other Graphs**
# These functions are all used to generate graphs for our program. These are extremely useful in interpreting the data as it shows any trends that may occur. They can only be created one at a time due to the large amounts of information being processed.

# %% [markdown]
# ### AI Prompts:
#
# 1. **Generate sample code for making a time series graph when given the parameters speed and time.**
# We asked ChatGPT this question in order to check the work we had previously done. Our graph was generated but it was very messy due to the large number of data points. Using the results from this prompt we were able to make the graph more simple and more able to demonstrate the data. ChatGPT answered this question well, as it was similar to the work we had done in class and to the code we already had. We did not need to update the prompt.
#
# 2. **Create sample code for a speed vs acceleration curve based on Engine RPM**
# We asked ChatGPT this question in order to learn specifics on how to include Engine RPM into our scatterplot as it was not something we had learned. This showed us how to make the color of the points change depending on the corresponding Engine RPM while the positions change based on the speed and acceleration. The code was accurate but we had to enter another prompt in order for ChatGPT to create the infrastructure needed to have those variable colors.
#
# 3. **Example code for making a fuel efficiency map**
# We asked ChatGPT this question in order to determine the best way to go about creating a fuel efficiency map, we did this because we were unfamiliar with fuel efficiency maps and on how to create them in python. The code was very helpful and we were quickly able to modify it to fit our specific needs. We needed to update the prompt several times as the provided code was not detailed enough to accurately portray all of our many points so the graph needed to be more refined.
#
# 4. **Generate sample code for reading a CSV file with 9 columns with different information and to store the data in unique dictionaries and lists**
# We asked ChatGPT this question in order to help with the overwhelming amount of data provided, there was a lot of data that all needed to be sorted correctly or none of our future calculations would work. The AI generated helpful code that allowed us to separate the data into usable sections. We did have to update the prompt so it could help us determine the best way to separate the data from the different cars, as that started to create issues with our code. It was helpful with that issue as well.
#
# 5. **Create a function that will take in any kind or amount of numerical data and find the mean, and median.**
# We asked ChatGPT this question in order to help us develop the different functions for our program. We initially struggled with the functions not being able to accept the different sets of data and were trying to avoid having dozens of functions that all did essentially the same thing. The code was helpful, we did need to update the prompt to elaborate on the specific forms that the data would be in such as dictionaries and lists as the AI’s parameters did not include the correct form of data storage.
#
# 6. **I'm using Jupyter Notebook markdown cells and need to split some lines and maybe bold them how do I do this?**
# We asked ChatGPT this prompt while trying to transfer google docs writing into Jupyter Notebook and format it properly. Transferring straight from google docs resulted in all lines being continuous and not being split between the prompt and output. ChatGPT was able to help by providing different ways of seperating lines and also bolding text, we decided to bold the prompts we used instead of trying to split lines.

# %%
#imports all necessary modules such as random, pandas, and matplotlib
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

df = pd.read_csv("vehicle_dynamics_data.csv") #uses pandas to read the vehicle data csv file

#Data management (reading from .csv)
#The function below is not used in the program anymore, it was created before we learned about pandas and was our first iteration of file reading.
def read_vehicle_data(filename): #function for reading the data file
    vehicle_data = {} #dictionary that is ultimately returned
    with open(filename, "r") as file: #reads the file
        data = file.readlines() 
        
    data_list = [] #here to seperate things by , from data ^^^
    for i in range(len(data)): #loops the the length of data
        data_list.append(data[i].split(",")) #splits the lists by ,

    for i in data_list[0]: #loops through data_list[0] which is the first line in the file with all the key names
        vehicle_data[f"{i.replace("\n","")}"] = [] #sets each key in the vehicle_data dictionary to Time, Speed, Acceleration, etc 

    for i in range(1, len(data_list)): #loops through data_list
        for j in range(len(data_list[i])): #loops through individual indices of data_list
            try:
                vehicle_data[data_list[0][j].replace("\n","")].append(float(data_list[i][j])) #if the value is a float, converts to a float and adds to the corresponding list
            except:
                vehicle_data[data_list[0][j].replace("\n","")].append(data_list[i][j]) #if the value isn't convertable like a string its added normally
            
    
    return vehicle_data #returns the dictionary

#Data reading function that uses pandas
def organize_data(df):
    # Dictionary to store all organized data
    all_data = {}

    # Iterates through each row to check for VehicleTypes and adds it as a key if not already.
    for _, row in df.iterrows():
        car_type = row['VehicleType']
        
        # Convert the row to a dictionary and pops the VehicleType key
        row_data = row.to_dict()
        row_data.pop('VehicleType')

        # Ensure the car type exists in the dictionary. If not, adds it to the dictionary
        if car_type not in all_data:
            all_data[car_type] = {}

        # Adds all the other data into the specified cars
        for key, value in row_data.items():
            if key not in all_data[car_type]:
                all_data[car_type][key] = []
            all_data[car_type][key].append(value)

    return all_data #returns a dictionary of cars, with the values as dictionaries of parameters.



#Analysis (calculating metrics)

def fuel_efficiency(car_type,distance): #fuel efficiency function that takes in car_type and distance traveled as their parameters.
    delta_distance = 0 #delta_distance is the change in distance variable
    delta_distance_list = [] #list of delta_distance values
    fuel_stats = calculate_basic_statistics(organized_data[car_type]['FuelConsumption']) #uses the function to calculate basic stats on fuel consumption
    avg_fuel = float(fuel_stats["Mean"]) #calculates average fuel consumption
    for i in range(len(distance)): #loops through the length of the distance column for the specified car type
        delta_distance = 0 #resets change in distance to 0 each time
        try: #try and except block to catch exceptions such as out of bound errors
            delta_distance = distance[i+1] - distance[i] #delta_distance find change in distance by subtracting the next index by the current index
            delta_distance_list.append(delta_distance) #appends the list with the change in distance at that index
        except:
            continue

    delta_distance_array = np.array(delta_distance_list) #converts the list to a numpy array
    avg_delta_distance = delta_distance_array.mean() #calculates the average of all changes in distance
    avg_fuel_efficiency = avg_delta_distance / avg_fuel #calculates fuel efficiency by dividing the change in distance by the fuel used
    
    return avg_delta_distance, avg_fuel_efficiency #returns the change in distance average and average fuel efficiency


# Calculating Basic Statistics
def calculate_basic_statistics(data):

    # Calculates mean, median, and std of a list
    mean = np.mean(data)
    median = np.median(data)
    std = np.std(data)

    # Gets the minimum and maximum of the list
    max_val = np.max(data)
    min_val = np.min(data)

    # Returns the results as a dictionary, each with respective keys
    return {"Mean": mean, "Median": median, "Standard Deviation": std, "Maximum Value": max_val, "Minimum Value": min_val}



#Visualization (matplot)

def generate_time_series_graphs(graph_type, car_type, data): #function for generating time series graphs, takes in graph type (all or individual), car type and data
    speed_mps = data[car_type]["Speed"] # * 1000 / 3600  # convert to m/s
    data[car_type]["Distance"] = np.cumsum(speed_mps) / 1000  # km

    if graph_type == "all": #if the user wants to see all 3 cars in the graph this runs
            fig, axs = plt.subplots(5, 1, figsize=(14, 12), sharex=True) #creates 5 subplots
            fig.suptitle("Vehicle Parameters Time Series", fontsize=16) #adds a title

            for i in data: #loops through data
                axs[0].plot(data[i]["Time"], data[i]["Speed"], label = f"{i}: Speed (km/h)") #the first graph is a Speed vs Time graph
                axs[1].plot(data[i]["Time"], data[i]["Acceleration"], label = f"{i}: Acceleration (m/s²)") #second graph is Acceleration vs Time
                axs[2].plot(data[i]["Time"], data[i]["EngineRPM"], label = f"{i}: Engine RPM") #third is EngineRPM vs Time
                axs[3].plot(data[i]["Time"], data[i]["FuelConsumption"], label = f"{i}: Fuel Consumption (L/h)") #fourth is Fuel Consumption vs Time
                axs[4].plot(data[i]["Time"], data[i]["Distance"], label = f"{i}: Distance Traveled (km)") #fifth is Distance vs Time
   
            axs[0].set_ylabel("Speed (km/h)") #enables the lables and legend for each graph
            axs[0].legend(loc = 2)
            axs[1].set_ylabel("Acceleration")
            axs[1].legend(loc = 2)
            axs[2].set_ylabel("RPM")
            axs[2].legend(loc = 2)
            axs[3].set_ylabel("Fuel (L/h)")
            axs[3].legend(loc = 2)
            axs[4].set_ylabel("Distance (km)")
            axs[4].legend(loc = 2)
            plt.xlabel("Time") #sets the x-axis label
            plt.tight_layout(rect = [0, 0, 1, 0.96]) #tight_layout adjusts the subplots to ensure there isn't any overlap between graphs, and labels
            plt.show() #shows the plot
    else: #if the user doesn't type all this runs
        fig, axs = plt.subplots(5, 1, figsize=(14, 12), sharex=True) #same setup of graphs
        fig.suptitle("Vehicle Parameters Time Series", fontsize=16) #same title


        #The only thing different is that instead of looping through data and using all car types it only generates the graphs for the specified car type.
        axs[0].plot(data[car_type]["Time"], data[car_type]["Speed"], label = f"{car_type}: Speed (km/h)")
        axs[1].plot(data[car_type]["Time"], data[car_type]["Acceleration"], label = f"{car_type}: Acceleration (m/s²)")
        axs[2].plot(data[car_type]["Time"], data[car_type]["EngineRPM"], label = f"{car_type}: Engine RPM")
        axs[3].plot(data[car_type]["Time"], data[car_type]["FuelConsumption"], label = f"{car_type}: Fuel Consumption (L/h)")
        axs[4].plot(data[car_type]["Time"], data[car_type]["Distance"], label = f"{car_type}: Distance Traveled (km)")

        #Same labeling and graphing functions as above
        axs[0].set_ylabel("Speed (km/h)")
        axs[0].legend(loc = 2)
        axs[1].set_ylabel("Acceleration")
        axs[1].legend(loc = 2)
        axs[2].set_ylabel("RPM")
        axs[2].legend(loc = 2)
        axs[3].set_ylabel("Fuel (L/h)")
        axs[3].legend(loc = 2)
        axs[4].set_ylabel("Distance (km)")
        axs[4].legend(loc = 2)
        plt.xlabel("Time")
        plt.tight_layout(rect = [0, 0, 1, 0.96])
        plt.show()


def generate_speed_acceleration_curve(car_type, data): #speed vs acceleration scatter plot graph, takes in car_type and data
    
    plt.figure(figsize = (12, 7)) #creates a plot

    sc = plt.scatter( #scatter plot 
        data[car_type]["Speed"], #x-axis is speed values of the car type
        data[car_type]["Acceleration"], #y-axis is acceleration values of the car type
        c = data[car_type]["EngineRPM"], #side bar with EngineRPM values
        #s = data[car_type]["FuelConsumption"] * 10,  # scale size
        cmap = "viridis", #maps colors based on engineRPM
        alpha = 0.7, #.7 opacity, slightly transparente
        edgecolor = "k" #sets the edge color to black
    )

    plt.colorbar(sc, label = "Engine RPM") #creates the sidebar
    plt.title("Speed vs Acceleration Curve") #adds the title
    plt.xlabel("Speed (km/h)") #sets x axis label
    plt.ylabel("Acceleration (m/s²)") #sets y axis label
    plt.grid(True) #enables the grid
    plt.tight_layout() #prevents overlap
    plt.show() #shows the plot

def generate_fuel_efficiency_map(car_type, data, grid_res=100): #function for generating a map of fuel efficiency, takes in car type, and data
    speed = np.array(data[car_type]["Speed"]) #numpy array of speed values
    rpm = np.array(data[car_type]["EngineRPM"]) #numpy array of rpm values
    distance = np.array(data[car_type]["Distance"]) #numpy array of distance values
    fuel = np.array(data[car_type]["FuelConsumption"]) #numpy array of fuel values

    # Avoid division by zero
    with np.errstate(divide='ignore', invalid='ignore'):
        fuel_eff = np.where(fuel != 0, distance / fuel, 1e-10)

    # Filter valid points (all arrays must be same length, with no NaNs)
    valid_mask = np.isfinite(speed) & np.isfinite(rpm) & np.isfinite(fuel_eff)
    x = speed[valid_mask] #filters the speed values to be in range
    y = rpm[valid_mask] #filters the rpm values to be in range
    z = fuel_eff[valid_mask] #filters the fuel efficiency values to be in range

    # Create grid
    xi = np.linspace(min(x), max(x), grid_res) #x-axis of speed values from the minimum speed to maximum
    yi = np.linspace(min(y), max(y), grid_res) #y-axis of rpm values from the minimum rpm to maximum
    xi, yi = np.meshgrid(xi, yi) #creates a 2D grid of x and y values

    # Interpolate
    zi = griddata((x, y), z, (xi, yi), method="cubic") 

    # Plot
    plt.figure(figsize=(12, 7)) #creates a new figure for the plot
    contour = plt.contourf(xi, yi, zi, cmap="viridis") #contour with a color map
    plt.colorbar(contour, label="Fuel Efficiency (km/L)") #creates a sidebar for fuel efficiency values/colors
    plt.xlabel("Speed (km/h)") #sets the x axis label
    plt.ylabel("Engine RPM") #sets the y axis label
    plt.title(f"Fuel Efficiency Map for the {car_type} car") #sets the title of the plot
    plt.show()



#Custom Functions

def fuel_cost(car_type): #custom function for fuel cost
    cost = random.uniform(3,6) #cost is a random number between 3 and 6, these were determined by searching for the maximum and minimum fuel cost in the US.
    travel_expense = cost * fuel_efficiency(car_type, organized_data[car_type]["Distance"])[0] #travel cost is the fuel cost times the average change in distance
    
    return travel_expense #returns the cost to travel on average

def traffic_violations(road_type, speed): #custom function for traffic violations, takes in road type and the speed
    speed_limit = { #speed limit values found by searching for speed limits on highways and in urban environments
        "highway" : 70,
        "urban" : 35
    }
    
    traffic_violations = 0 #variable for traffic violations, over speed limit
    reckless_driving = 0 #variable for reckless driving, twice the speed limit or more
    
    if road_type == "highway": #checks for road_type
        for i in range(0, len(speed), 100): #loops throught the length of the speed values, checks every 100 rows for the speed
            if speed[i] > speed_limit["highway"] * 2: #if speed at the current index is twice the legal limit it adds a violation to reckless driving
                reckless_driving = reckless_driving + 1
            elif speed[i] > speed_limit["highway"]: #else if speed is above the legal limit but less than 2x, adds to a regular traffic violation
                traffic_violations = traffic_violations + 1
    elif road_type == "urban": #checks for road type
        for i in range(0, len(speed), 100): #same loop
            if speed[i] > speed_limit["urban"] * 2: #same classification for violations
                reckless_driving = reckless_driving + 1
            elif speed[i] > speed_limit["urban"]: #same classification for violations
                traffic_violations = traffic_violations + 1

    return traffic_violations, reckless_driving #returns the number of regular traffic violations and counts of reckless driving
                

def ui(): #user input/user UI function
    car_type = 0 
    graph_type = 0

    valid_inputs = False #boolean to check that all inputs are valid
    
    while not valid_inputs: #loops until valid inputs is (not True) = false
        while car_type not in car_types: #loops while the user input is not a valid car type
            car_type = input("What car do you want to see? [sedan, suv, sports]: ")
            if car_type not in car_types:
                print("Please enter a valid car type")

        while graph_type not in allowed_graphs: #loops while the graph type isn't valid
            graph_type = input("What kind of graph do you want to produce? ['all', 'individual'] ('all' produces graphs with all car types): ")
            if graph_type not in allowed_graphs:
                print("Please enter a valid car type")

        valid_inputs = True #sets valid_inputs to True which means the outermost loop = False and terminates

    return car_type, graph_type #returns the car type and graph type user inputs


def generate_report(car_type, traffic_violations, fuel_efficiency, data): #function for generating a typed out report
    print()
    print("Vehicle Analysis Report") #title
    print()

    #Minimum values aren't included because all of them would be 0
    print("Vehicle Speed Analysis:") 
    print(" - Average Speed:", calculate_basic_statistics(data[car_type]["Speed"])["Mean"], "km/hr") #average/mean speed
    print(" - Maximum Speed:", calculate_basic_statistics(data[car_type]["Speed"])["Maximum Value"], "km/hr") #max speed
    print()
    
    print("Vehicle Acceleration Analysis:")
    print(" - Average Acceleration:", calculate_basic_statistics(data[car_type]["Acceleration"])["Mean"], "m/s²") #average/mean acceleration
    print(" - Maximum Acceleration:", calculate_basic_statistics(data[car_type]["Acceleration"])["Maximum Value"], "m/s²") #maximum acceleration
    print()

    print("Vehicle EngineRPM Analysis:")
    print(" - Average EngineRPM:", calculate_basic_statistics(data[car_type]["EngineRPM"])["Mean"], "RPM") #average engine rpm
    print(" - Maximum EngineRPM:", calculate_basic_statistics(data[car_type]["EngineRPM"])["Maximum Value"], "RPM") #max engine rpm
    print()

    print("Vehicle Fuel Consumption Analysis:")
    print(" - Average Fuel Consumption:", calculate_basic_statistics(data[car_type]["FuelConsumption"])["Mean"], "L") #average fuel consumption
    print(" - Maximum Fuel Consumption:", calculate_basic_statistics(data[car_type]["FuelConsumption"])["Maximum Value"], "L") #max fuel consumption
    print()

    print("Vehicle Fuel Efficiency Analysis:")
    print(" - Average Fuel Efficiency:", fuel_efficiency[1], "km/L") #average fuel efficiency
    print()

    print("Vehicle Distance Analysis:")
    print(" - Average Distance:", calculate_basic_statistics(data[car_type]["Distance"])["Mean"], "km") #average distance
    print(" - Maximum Distance:", calculate_basic_statistics(data[car_type]["Distance"])["Maximum Value"], "km") #maximum distance
    print()

    print("Traffic Violations:")
    print(" - Number of Traffic Violations:", traffic_violations[0]) #number of regular traffic violations
    print(" - Counts of Reckless Driving:", traffic_violations[1]) #counts of reckless driving
    print()
    


### Beyond is where the program is actually run, and where functions are called

car_types = ['sedan', 'suv', 'sports'] #allowable car types for the UI
allowed_graphs = ["all", "individual"] #allowable graph types for the UI

organized_data = organize_data(df) #organizes the data using pandas and splits by car type

user_interface = ui() #runs the ui function, saves the car_type and graph_type input

car_type = str(user_interface[0]) #car_type is the the first user input converted to a string
graph_type = str(user_interface[1]) #graph_type is the second user input converted to a string
fuel_efficiency = fuel_efficiency(car_type, organized_data[car_type]["Distance"]) #uses the fuel efficiency function with the user specified car type and distance
road_type = organized_data[str(user_interface[0])]["ProfileType"][0] #uses organized data and identifies the road type for the vehicle (only uses the first row)
speed_list = organized_data[str(user_interface[0])]["Speed"] #uses organized data to find all speed values

violations = traffic_violations(road_type, speed_list) #uses the traffic_violations function to return the number of regular violations and reckless driving

generate_report(car_type, violations, fuel_efficiency, organized_data) #generates the report using the given car type, violations, fuel efficiency, and data


generate_time_series_graphs(graph_type, car_type, organized_data) #generates the time series graph
generate_speed_acceleration_curve(car_type, organized_data) #generates the speed vs acceleration scatter plotgraph
generate_fuel_efficiency_map(car_type, organized_data) #generates the fuel efficiency map graph
# Out:
# What car do you want to see? [sedan, suv, sports]:  sports
# What kind of graph do you want to produce? ['all', 'individual'] ('all' produces graphs with all car types):  individual
# Vehicle Analysis Report
#
# Vehicle Speed Analysis:
#  - Average Speed: 71.33667608027494 km/hr
#  - Maximum Speed: 130.0890983250277 km/hr
#
# Vehicle Acceleration Analysis:
#  - Average Acceleration: -0.023392755838314173 m/s²
#  - Maximum Acceleration: 59.23226829519635 m/s²
#
# Vehicle EngineRPM Analysis:
#  - Average EngineRPM: 1733.2669858939014 RPM
#  - Maximum EngineRPM: 2445.5430891107844 RPM
#
# Vehicle Fuel Consumption Analysis:
#  - Average Fuel Consumption: 10.544530996881297 L
#  - Maximum Fuel Consumption: 51.6158059286611 L
#
# Vehicle Fuel Efficiency Analysis:
#  - Average Fuel Efficiency: 0.18791761412751617 km/L
#
# Vehicle Distance Analysis:
#  - Average Distance: 12579.912943272731 km
#  - Maximum Distance: 23778.89202675856 km
#
# Traffic Violations:
# ...

# %% [markdown]
# ### AI Reflection
# Our goal for this project was not to rely too heavily on AI, making our prompts asking for help rather than for the answer. This allowed us to better understand the code and we were able to edit it when errors occurred far easier than if AI had written it. We had AI explain complex problems and provide examples rather than writing all of the code for us. Using AI as a tool instead of a crutch gave us a better understanding of the capabilities of AI as we could explain the problem and it offered solutions. We generally enjoyed the use of AI in this project as it was able to make the most difficult parts of the project easier to handle and understand. There were not too many occasions where the AI was outright incorrect about something which allowed us to minimize the time spent correcting its errors, instead spending that time correcting our own. This process did save us time which was much appreciated as we did not have to spend time researching or looking through our notes when we ran into a complex issue, we could instead consult with the AI which could usually find the problem quickly. Generally we used the AI to help explain the concepts that we had not encountered before, although we tried to only interact with them as far as the assignment required it, other than the specifically required actions we tried to stay away from things we had no experience with as that would make troubleshooting far more difficult. Overall the use of AI made this project easier which make us happy about using it, but we did not have it complete all of the code for us so we still had a strong sense of accomplishment and pride in our work, pride that is bolstered by our use of AI.
